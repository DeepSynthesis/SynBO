# %%
import pandas as pd

df = pd.read_csv('../Co-enamine.csv')

# %%
from qspoc.utils import canonicalize_input_SMILES_file

for col in ["amine_smiles_ion","amine_smiles_anion","oxidant_smiles","alkali_smiles","solvent_smiles"]:
    canonicalize_input_SMILES_file('../Co-enamine.csv', col)

# %%
for col in ["amine_smiles_ion"]:
    df[col].drop_duplicates().to_csv(f'reagents/{col}1.csv', index=False)

# %%
from qspoc.utils import smileslist2png

for col in ['amine_smiles_ion','amine_smiles_anion','cobalt_smiles','oxidant_smiles','alkali_smiles','solvent_smiles']:
    df = pd.read_csv(f'reagents/{col}.csv')
    smileslist2png(df[col], savepath=f'reagents/pics/{col}', show_index=True, highlight_atoms_list=df['atom_idx'])
# Out:
# 100%|██████████| 30/30 [00:01<00:00, 25.66it/s]
# 100%|██████████| 4/4 [00:00<00:00, 29.04it/s]
# 100%|██████████| 14/14 [00:00<00:00, 22.45it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/AIChem/reactionopt/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'atom_idx'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 5
#       3 for col in ['amine_smiles_ion','amine_smiles_anion','cobalt_smiles','oxidant_smiles','alkali_smiles','solvent_smiles']:
#       4     df = pd.read_csv(f'reagents/{col}.csv')
# ----> 5     smileslist2png(df[col], savepath=f'reagents/pics/{col}', show_index=True, highlight_atoms_list=df['atom_idx'])
#
# File ~/AIChem/reactionopt/.venv/lib/python3.13/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~/AIChem/reactionopt/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'atom_idx'
